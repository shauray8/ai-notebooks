# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../data/gapminder_rosling/income_per_person_gdppercapita_ppp_inflation_adjusted.csv")

# %%
df.head()
# Out:
#                 country  1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# 0           Afghanistan   603   603   603   603   603   603   603   603   603
# 1                Angola   618   620   623   626   628   631   634   637   640
# 2               Albania   667   667   667   667   667   668   668   668   668
# 3               Andorra  1200  1200  1200  1200  1210  1210  1210  1210  1220
# 4  United Arab Emirates   998  1000  1010  1010  1010  1020  1020  1020  1030
#
#    ...   2031   2032   2033   2034   2035   2036   2037   2038   2039   2040
# 0  ...   2550   2600   2660   2710   2770   2820   2880   2940   3000   3060
# 1  ...   6110   6230   6350   6480   6610   6750   6880   7020   7170   7310
# 2  ...  19.4k  19.8k  20.2k  20.6k    21k  21.5k  21.9k  22.3k  22.8k  23.3k
# 3  ...  73.6k  75.1k  76.7k  78.3k  79.8k  81.5k  83.1k  84.8k  86.5k  88.3k
# 4  ...  66.8k  68.1k  69.4k  70.8k  72.2k  73.7k  75.2k  76.7k  78.3k  79.9k
#
# [5 rows x 242 columns]

# %%
sns.displot(df.head(5), x="country", y="1800", kind="kde")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4304c8c15a58> in <module>
# ----> 1 sns.displot(df.head(5), x="country", y="1800", kind="kde")
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2190     else:
#    2191         allowed_types = None
# -> 2192     p._attach(g, allowed_types=allowed_types, log_scale=log_scale)
#    2193
#    2194     # Check for a specification that lacks x/y data and return early
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\seaborn\_core.py in _attach(self, obj, allowed_types, log_scale)
#    1101                     f"{allowed_types} is required"
# ...

# %%
sns.pairplot(df.head())

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df["1801"], df.country, 
                  color='darkblue', 
                 alpha=0.5,
           s=df["1801"]//2)
plt.scatter(df["1800"], df.country, 
                  color='red', 
                 alpha=0.5,
            s=df["1800"]//2
                 )
plt.xlabel("Years", size=14)
plt.ylabel("Number of immigrants", size=14)
# Out:
# Text(0, 0.5, 'Number of immigrants')
