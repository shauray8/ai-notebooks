# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import plotly.express as px
import plotly
sns.set_theme(style="darkgrid")
import matplotlib.path as mpath
from matplotlib.figure import Figure

# %%
df_india = pd.read_csv("india-gdp-growth-rate.csv")
df_china = pd.read_csv("china-gdp-growth-rate.csv")

df_india_lit = pd.read_csv("india-literacy-rate.csv")
df_china_lit = pd.read_csv("china-literacy-rate.csv")

df_debt = pd.read_csv("india-debt-to-gdp-ratio.csv")
df_tax = pd.read_csv("india_tax_revenue.csv")

df_mortality = pd.read_csv("india-china-mortality-rate.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-510fa87287c0> in <module>
# ----> 1 df_india = pd.read_csv("india-gdp-growth-rate.csv")
#       2 df_china = pd.read_csv("china-gdp-growth-rate.csv")
#       3
#       4 df_india_lit = pd.read_csv("india-literacy-rate.csv")
#       5 df_china_lit = pd.read_csv("china-literacy-rate.csv")
#
# ...

# %%
df_india["date"] = pd.to_datetime(df_india['date'])
df_china["date"] = pd.to_datetime(df_china['date'])
df_india_lit["date"] = pd.to_datetime(df_india_lit['date'])
df_china_lit["date"] = pd.to_datetime(df_china_lit['date'])

df_debt["date"] = pd.to_datetime(df_debt['date'])
df_tax["date"] = pd.to_datetime(df_tax['date'])

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df_china.head()
# Out:
#         date   GDP ( Billions of US $)   Per Capita (US $)   GDP Growth (%)  \
# 0 1962-12-31                 47.209359             70.9094            -5.58
# 1 1963-12-31                 50.706800             74.3136            10.30
# 2 1964-12-31                 59.708343             85.4986            18.18
# 3 1965-12-31                 70.436266             98.4868            16.95
# 4 1966-12-31                 76.720286            104.3246            10.65
#
#     Annual Change
# 0           21.69
# 1           15.88
# 2            7.88
# 3           -1.23
# 4           -6.30

# %%
fig, ax = plt.subplots()
plt.plot(df_india["date"].head(), df_india[" Per Capita (US $)"].head())

# %%
df_india[" annual_change"].plot()
# Out:
# <AxesSubplot:>

# %%
for i in range(len(df_india.columns)):
    usefull = df_india.columns[i].split(" ")
    
df_india_lit.head()
# Out:
#         date  Literacy Rate Unnamed: 2 Unnamed: 3
# 0 1981-12-31        40.7636        NaN        NaN
# 1 1991-12-31        48.2221        NaN        NaN
# 2 2001-12-31        61.0146        NaN        NaN
# 3 2006-12-31        62.7545        NaN        NaN
# 4 2011-12-31        69.3026        NaN        NaN

# %%
df_india_lit.columns[1]
# Out:
# ' Literacy Rate'

# %%
fig, ax = plt.subplots()
plt.style.use("dark_background")
ax.stackplot(df_china_lit['date'], df_china_lit[" Literacy Rate"], labels=["China"], alpha=.7)
ax.stackplot(df_india_lit['date'], df_india_lit[" Literacy Rate"], labels=["India"], alpha=.7)
ax.legend(loc='upper left')
# x = []
# for i in range(0,len(df_india["date"]),5):
#     x.append(df_india["date"][i])
# x.append(df_india["date"][len(df_india["date"])-1])
plt.xticks(rotation=90)
plt.xticks(df_india_lit['date'])
ax.set_title('Debt to Gdp ratio')
ax.set_xlabel('Year')
ax.set_ylabel('Debt to Gdp')
#plt.savefig('debtto_gdp_india_china.png', dpi=1200,bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-376-393e1d3cb975> in <module>
#       1 fig, ax = plt.subplots()
#       2 plt.style.use("dark_background")
# ----> 3 ax.plot(df_china_lit['date'], df_china_lit[" Literacy Rate"], labels=["China"], alpha=.7)
#       4 ax.stackplot(df_india_lit['date'], df_india_lit[" Literacy Rate"], labels=["India"], alpha=.7)
#       5 ax.legend(loc='upper left')
#
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ...

# %%
df_debt.columns
# Out:
# Index(['date', ' Government Debt as % of GDP', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
fig, ax = plt.subplots()
plt.style.use("dark_background")
ax.stackplot(df_debt['date'], df_debt[" Government Debt as % of GDP"], labels=["India"], alpha=.7)
ax.legend(loc='upper left')
# x = []
# for i in range(0,len(df_tax["date"]),5):
#     x.append(df_tax["date"][i])
# x.append(df_tax["date"][len(df_tax["date"])-1])
plt.xticks(rotation=90)
plt.xticks(df_debt['date'])
ax.set_title('Debt to GDP ratio')
ax.set_xlabel('Year')
ax.set_ylabel('Debt to GDP %')
plt.savefig('debt_to_gdp_ratio_india.png', dpi=1200,bbox_inches="tight")
