# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import plotly.express as px
import plotly

# %%
df = pd.read_csv("../../data/gapminder_rosling/income_per_person_gdppercapita_ppp_inflation_adjusted.csv")

# %%
df.head()
# Out:
#                 country  1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# 0           Afghanistan   603   603   603   603   603   603   603   603   603
# 1                Angola   618   620   623   626   628   631   634   637   640
# 2               Albania   667   667   667   667   667   668   668   668   668
# 3               Andorra  1200  1200  1200  1200  1210  1210  1210  1210  1220
# 4  United Arab Emirates   998  1000  1010  1010  1010  1020  1020  1020  1030
#
#    ...   2031   2032   2033   2034   2035   2036   2037   2038   2039   2040
# 0  ...   2550   2600   2660   2710   2770   2820   2880   2940   3000   3060
# 1  ...   6110   6230   6350   6480   6610   6750   6880   7020   7170   7310
# 2  ...  19.4k  19.8k  20.2k  20.6k    21k  21.5k  21.9k  22.3k  22.8k  23.3k
# 3  ...  73.6k  75.1k  76.7k  78.3k  79.8k  81.5k  83.1k  84.8k  86.5k  88.3k
# 4  ...  66.8k  68.1k  69.4k  70.8k  72.2k  73.7k  75.2k  76.7k  78.3k  79.9k
#
# [5 rows x 242 columns]

# %%
plt.scatter(x=df["country"], y=df["1800"])

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df["1801"], df.country, 
                  color='darkblue', 
                 alpha=0.5,
           s=df["1801"]//2)
plt.scatter(df["1800"], df.country, 
                  color='red', 
                 alpha=0.5,
            s=df["1800"]//2
                 )
plt.xlabel("Years", size=14)
plt.ylabel("Number of immigrants", size=14)
# Out:
# Text(0, 0.5, 'Number of immigrants')

# %%
country_data = px.data.gapminder()
country_data.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
map_fig = px.scatter_geo(country_data, locations = "iso_alpha",
                         projection = "orthographic",
                         color = "continent",
                         opacity = .7,
                         hover_name = "country",
                        hover_data = ["lifeExp", "pop", "gdpPercap"],
                        )
map_fig.show()
# Out:
# <div>                            <div id="1a325a92-a3e8-4ad9-9baf-f2f32b5505f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a325a92-a3e8-4ad9-9baf-f2f32b5505f1")) {                    Plotly.newPlot(                        "1a325a92-a3e8-4ad9-9baf-f2f32b5505f1",                        [{"customdata":[[28.801,8425333.0,779.4453145],[30.331999999999997,9240934.0,820.8530296],[31.997,10267083.0,853.1007099999999],[34.02,11537966.0,836.1971382],[36.088,13079460.0,739.9811057999999],[38.438,14880372.0,786.11336],[39.854,12881816.0,978.0114388000001],[40.821999999999996,13867957.0,852.3959447999999],[41.674,16317921.0,649.3413952000001],[41.763000000000005,22227415.0,635.341351],[42.129,25268405.0,726.7340548],[43.828,31889923.0,974.5803384],[50.9389
# ...

# %%
plotly.offline.plot(map_fig, filename = "gdp.html", auto_open=True)
# Out:
# 'gdp.html'

# %%
fig = px.density_mapbox(df, lat = "country", lon = "1800", 
                       z = "1801", radius = 10, 
                       center = dict(lat = 9, lon = 9),
                       zoom = 1,
                       hover_name = "country",
                       mapbox_style = "stamen-watercolor",
                       title = "gdp try")

fig.show()
# Out:
# <div>                            <div id="9603d6c4-09d7-483a-9bd0-6abf91274943" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9603d6c4-09d7-483a-9bd0-6abf91274943")) {                    Plotly.newPlot(                        "9603d6c4-09d7-483a-9bd0-6abf91274943",                        [{"coloraxis":"coloraxis","hovertemplate":"<b>%{hovertext}</b><br><br>1801=%{z}<br>country=%{lat}<br>1800=%{lon}<extra></extra>","hovertext":["Afghanistan","Angola","Albania","Andorra","United Arab Emirates","Argentina","Armenia","Antigua and Barbuda","Australia","Austria","Azerbaijan","Burundi","Belgium","Benin","Burkina Faso","Bangladesh","Bulgaria","Bahrain","Bahamas","Bosnia and Herzegovina","Belarus","Belize","Bolivia","Brazil","Barbados","Brunei","Bhutan","B
# ...

# %%
plotly.offline.plot(fig, filename = "gdp.html", auto_open=True)
# Out:
# 'gdp.html'

# %%
fig = px.scatter(df, x="1800",
                 y="country", size="1800", color="country",
           hover_name="country", log_x=True, size_max=60)
fig.show()
# Out:
# <div>                            <div id="ce0f8a06-34e9-406b-9e0a-55ab228a0ed3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce0f8a06-34e9-406b-9e0a-55ab228a0ed3")) {                    Plotly.newPlot(                        "ce0f8a06-34e9-406b-9e0a-55ab228a0ed3",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{y}<br>1800=%{marker.size}<extra></extra>","hovertext":["Afghanistan"],"legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[603],"sizemode":"area","sizeref":1.0666666666666667,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"h","showlegend":true,"type":"scatter","x":[603],"xaxis":"x","y":["Afghanistan"],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{y}<br>
# ...

# %%
plotly.offline.plot(fig, filename = "gdp.html", auto_open=True)
# Out:
# 'gdp.html'

# %%
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", 
                animation_frame="year", animation_group="country",
                size="pop", color="continent", hover_name="country", 
                 size_max=45, range_x=[-1000,60000], range_y=[25,90])
fig.show()
# Out:
# <div>                            <div id="27fee1ce-eff7-48d3-8783-5740fe33de6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27fee1ce-eff7-48d3-8783-5740fe33de6c")) {                    Plotly.newPlot(                        "27fee1ce-eff7-48d3-8783-5740fe33de6c",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>continent=Asia<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Ta
# ...

# %%
fig = px.scatter_geo(df, locations="iso_alpha", color="continent", 
                     hover_name="country", size="pop",
               animation_frame="year", projection="orthographic")
fig.show()
# Out:
# <div>                            <div id="22a23ef1-80c7-4033-b50a-33bdba805b75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22a23ef1-80c7-4033-b50a-33bdba805b75")) {                    Plotly.newPlot(                        "22a23ef1-80c7-4033-b50a-33bdba805b75",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>continent=Asia<br>year=1952<br>pop=%{marker.size}<br>iso_alpha=%{location}<extra></extra>","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria",
# ...

# %%
plotly.offline.plot(fig, filename = "pop.html", auto_open=True)
# Out:
# 'pop.html'
